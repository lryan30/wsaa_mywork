# %% [markdown]
# # **WSAA 1.1 Running HTML and Javascript:**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **JAVASCRIPT**

# %% [markdown]
# --   go to developer tools - console - can see the javascript in this which can be different to the display on the webpage. which says hello. (see hello2.html)
#
# -   normal users do not see the console.log. its handy for debugging.

# %% [markdown]
# ![image.png](attachment:image.png)
