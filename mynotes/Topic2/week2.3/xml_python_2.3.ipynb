# %% [markdown]
# ### **Topic 2.3: Consuming XML with Python**

# %% [markdown]
# **1.**  Read XML file: from local file system or fetch it from the web using an HTTP request.
#
# **2.**  Using Minidom to parse the XML. pythons built-in xml.dom.minidom module to parse the XML content.
#
# **3.**  Search up and down the dom tree using python. After parsing the XML, will look how to search the DOM tree for elements, both upward and downward.
#
# **4.**  Save the contents in a CSV file. extract data from XML and save to a CSV file using pythons csv module.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# parsers will read in the xml and make a document object model.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://docs.python.org/3/library/xml.dom.minidom.html
#
# https://docs.python.org/3/library/xml.dom.html

# %% [markdown]
# In documentation:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Example:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# DOM starts of at root element, if we want to get all the first names, we need to get the child elements.
# -   We do this by getting all the employee elements by tag name. All the nodes that have the tag name employee. for each of the nodes in the list we can get the info from there.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# -   Now, want to get the first child element which is called FirstName.
# -   And we want to get the firstName from the other employee also.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# -   list only contains one element but we only want the firstName, so item (0) will get us the first name.
# -   Now, want to get the text out of that.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The text is another node under the tags. its not part of the tag.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Javascript from webpage and create elements in webpages to put in new lines in table etc. very good for manipulating database tables.
