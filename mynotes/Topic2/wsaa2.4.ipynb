# %% [markdown]
# #### WSAA2.4 JSON slides

# %% [markdown]
# dict objects must be double quotes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import json
filename = "wsaa2.4-json.json"
with open(filename, "r") as fp:
    jsonobject = json.load(fp)
    print(jsonobject)
#for employee in jsonobject["employees"]:
    #print(employee)
    #print(employee["firstName"])
# Out:
# {'employees': [{'firstName': 'John', 'lastName': 'Doe'}, {'firstName': 'Anna', 'lastName': 'Smith'}, {'firstName': 'Peter', 'lastName': 'Jones'}]}

# %%
# json more simple than xml. 
# read from the cloud:
#import requests
#url="https://someurl.com"
#response = requests.get(url)
#data=response.json()
#print(data)

# %%
#import requests
#import json
#url = "https://api.coindesk.com/v1/bpi/currentprice.json"
#response = requests.get(url)
##print(response.json())
#data = response.json()
#with open ("bitcoindump.json", "w") as fp:
 #   json.dump(data, fp)
#euroPriceObject = data["bpi"]["EUR"]
#rate = euroPriceObject["rate"]
#print(rate)
#''''''

# %% [markdown]
# get current bitcoin price-->api.coindesk.com
