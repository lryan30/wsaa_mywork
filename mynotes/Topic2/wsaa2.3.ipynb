# %% [markdown]
# #### WSAA2.3 consuming xml with python:

# %% [markdown]
# Getting content into program
# -   read the file.
#
# with open(filename) as fp:

# %% [markdown]
# *Request module:*
# -   import requests
# -   page=requests.get('httpe0;//dataquestio.github.io/web-scraping-pages/simple.html')
# -   print(page)
# -   print('--------------')
# -   print (page.content)

# %% [markdown]
# built in minidom used as parser. many parsers you can use. (webparsing)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# xml file with two employees and each has 3 child nodes. elements first name last name and contact number as indicated by tags, each has a child node joe murphy 6 of type text.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  get document object module-->root-->child elements.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# first child node is a text node. then strip() to remove leading spaces before or afterwards.
# -   the tricky bit is the text is another node under the tags. not actual part of the tag its another node under the tags.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# javascript can read dfrom webpage and create elements in webpage and create new lines in a table etc. uselful for manipulating database tables.
