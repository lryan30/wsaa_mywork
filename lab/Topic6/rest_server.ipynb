# %% [markdown]
# ### **Lab 6:**

# %% [markdown]
# *Get all books:*
#
# ![image.png](attachment:image.png)

# %% [markdown]
# *Find book by id:*
#
# ![image.png](attachment:image.png)

# %% [markdown]
# *Create a book:*
#
# ![image.png](attachment:image.png)

# %% [markdown]
# *Update a book:*
#
# ![image.png](attachment:image.png)

# %% [markdown]
# *Delete a book:*
#
# ![image.png](attachment:image.png)
