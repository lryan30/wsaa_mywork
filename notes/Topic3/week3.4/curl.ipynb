# %% [markdown]
# ### **Topic 3.4 CURL:**
#
# -   Using Curl and Postman to test and debug HTTP, specifically the API on
# -   https://andrewbeatty1.pythonanywhere.com/books

# %% [markdown]
# CURL is a command line tool used to send HTTP requests and interact with web services or API's. It allows you to fetch data from a URL, submit forms, upload files all directly from the terminal command prompt.
#
# -   GET and POST requests
# -   Can include headers, parameters and authentication

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# can use postman or curl

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# -   gives header

# %% [markdown]
# To get one individual book (id:557)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# -   Should add internal error 202-no content

# %% [markdown]
# Add new book:
#
# -   -H --> header "content type-application/json" adds header specifiting the content type is JSON.
# -   -X post --> HTTP method for adding data
# -   -d -->data to be sent in the request body, you need to properly handle inverted commas.
# When sending JSON in the request body  "" json needs inverted commas. need to escape the inverted commas inside the inverted commas.
#
#       -     -d "{\"title\":\"New Book\",\"author\":\"LR\",\"year\":2025}": Sends the JSON data with the book details (note:quotes inside the JSON string are escaped with backslashes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# can delete the added book if needed:
#
# ```curl -x DELETE```

# %% [markdown]
# can use cmd line or postman.

# %% [markdown]
# ### **End**
# ***
