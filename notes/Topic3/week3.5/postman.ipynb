# %% [markdown]
# # **Topic 3.5: POSTMAN**

# %% [markdown]
# Postman helps you create HTTP requests up to a web-server.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Headers: can set different headers to go up.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Set the body of the request:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Use POST to create new book to send to webpage
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Look at headers:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### **End**
# ***
