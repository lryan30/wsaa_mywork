# %% [markdown]
# ### **Topic 3.3: RESTful API**

# %% [markdown]
# HTTP, status codes and methods -->how people designed these to make API's. Make an application that can be interacted with through the cloud.
#
# Application Program Interface --> An interface that a program that you write can use to transfer data to another program.

# %% [markdown]
# **RESTful API:**
#
# -   Representational State Transfer APIs are a type of web API that follow the principles of REST architecture.
# -   These API's allow different software systems to communicate over the internet using HTTP methods --> GET, POST, PUT, DELETE etc.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# idempotency-->if you have same request twice it wouldnt do it twice. if the request reaches the server twice by mistake it doesnt do it twice. so sometimes requests have idempotency.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Both APIs work same but can be designed differently. Need to look at the documentation to see how it is designed.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Note: In windows machine need to escape out inverted commas. (on cmd line)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Note: Not always stateless.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Cacheing can be difficult

# %% [markdown]
# Sites that use RESTful API's:
#
# -   Facebook, google, stripe, CSO etc
# -   publicapis.io
# -   Python has packages that can handle these API's

# %% [markdown]
# https://andrewbeatty1.pythonanywhere.com/books
#
# ![image.png](attachment:image.png)

# %% [markdown]
# -   in JSON
# -   check developer tools.

# %% [markdown]
# If want just one book for example book id 545: add 545 at end of the URL.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# To add new book:
#
# -   go to postman
# -   add url
# -   create new book, select post
# -   content type application json
# -   raw
# -   body -json
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Gmail API, Dropbox API,-->check if new file in there etc, Google docs API's

# %% [markdown]
# Summary:
#
# -   REST is a loose set of constraints/guidelines used for making an API
# -   stateless: Each request is independent and the server doesnt store any session information
# -   cacheable: responses can be cached  to improve performance. Cache refers to a temporary storage location where data can be stored for quick access. In web applications and API's caching involves storing frequently accessed data in a faster storage medium such as memory so that future requests for the same data can be served more qucikly without needing to access the original source again.
# -   Use HTTP methods
