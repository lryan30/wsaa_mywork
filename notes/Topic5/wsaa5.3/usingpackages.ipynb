# %% [markdown]
# ### **Topic5.3: Using Packages**

# %% [markdown]
# python packages designed to interact with APIs.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# sending emails via python-->check google developer documentation
#
# ![image.png](attachment:image.png)

# %% [markdown]
# sample code for sending and receiving emails etc
