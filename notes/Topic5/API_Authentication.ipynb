# %% [markdown]
# ### **Topic5.1: API authentication**

# %% [markdown]
# The simplest way an API can restrict access is through the use of API keys.
#
# API key-->limit amount of time to access data. can cause servers to overload.
# -   can be sensitive data.
# -   monetisation
#
# Also, you may want to create an application that other users can interact with their accounts with, (without giving them your details. may not want to store their password).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# -   may need to send them an email to get API key. secure site etc.

# %% [markdown]
# *html2pdf.app*
# -   go to documentation
# -   authentication
# -   copy api url https://api.html2pdf.app/v1/generate?html=https://example.com&apiKey={your-api-key}
#     -   contains url you want to convert to pdf
#        -   and url key
# -   other pararmeters also for example callbackurl etc
#
# Need to register to get API key.
# -   go to API keys and generate a new API key. and then will put into the code and get webpages converted to pdf.
#
# -   put keys into config file, and add to gitignore so it doesnt go up to github.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# For private repo's will need an API token to get it.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# oAuth2 lets one app access some data from another app, without giving away your password. (Stripe uses oauth2 for connect-multi platform accounts. For most apps using stripe oauth isnt needed, just use own API keys.)

# %% [markdown]
# -   https://docs.github.com/en/rest?apiVersion=2022-11-28
#
# -   https://github.com/PyGithub/PyGithub
#
# -   https://oauth.net/2/
#
# -   https://apilayer.com/
#
# -   https://rapidapi.com/blog/most-popular-api/
#
# -   https://apilist.fun/
#
# -   https://publicapis.io/
