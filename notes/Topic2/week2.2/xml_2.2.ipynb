# %% [markdown]
# ### **Topic 2.2: XML and the DOM**

# %% [markdown]
# **XML**
#
# *eXtensible Markup Language*
#
# -   Extensible: Designed to accommodate change.
# -   Markup: Annotates text.
# -   Language: Set of rules for communication.

# %% [markdown]
# XML is a format used to store and transport data in a structured way, using a set of rules that is human and machine readable.

# %% [markdown]
# XML is the follow on from HTML. HTML was a very good way of passing information or data from computers of different types. for example: how to display a document. Then decided XML would be good later on.

# %% [markdown]
# Example of XML:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If you want anything dynamic in a webpage you need to use javascript.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# xml flexible in displaying xml.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In python or javascript you can manipuate the DOM of a webpage. and if you do it in webbrowsers you can manipulate how the page looks, (as in you can put in new html tags etc.)--> javascript and Jquery. Jquery is a set of libraries that goes with Javascript.
#
# -   The DOM represents the structure of the HTML document and it allows you to interact with the elements of the page dynamically.
# -   With Javascript you can add, remove or modify HTML elements and their content. This allows you to change how the webpage looks and behaves after the page has loaded.

# %% [markdown]
# *DOM: Each node in DOM has three parts*
#
# ![image.png](attachment:image.png)

# %% [markdown]
# -   *Element:* --> open/closed tag. (elements can have sub-elements and sub notes). Elements have Name and no value
# -   *Attribute:* --> that is inside a tag of an element. Name, value, pair attributes. Attributes have name and value.
# -   *Text:* --> Has name but no value.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# -   root node--> <company>-->element
# -   <company> has 4 nodes which are all elements.<employee>
# -   <employee> element has one attribute called category='technical'
# -   <firstname> element (1 node of type text: joe)  etc.-->lastname, contact no.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# HTML page which is just like XML.
# -   can have scripts which can manipulate the page.

# %% [markdown]
# ### **END**
# ***
