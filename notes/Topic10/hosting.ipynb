# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# -   click bash and git clone
# -   web app-->add new web app
# -   flask server
# -

# %% [markdown]
# ![image.png](attachment:image.png)
