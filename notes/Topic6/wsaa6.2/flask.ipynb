# %% [markdown]
# ### **Topic6.2 Flask**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  * Running on http://127.0.0.1:5000 -->open up in browser
#
#  ![image.png](attachment:image.png)

# %% [markdown]
# developer tools-->check console to ensure everything is fine.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# -   if you make changes -->debug mode is on -->restarts server
# -   FLask is an app server.
# -   There are two ways of running it.
