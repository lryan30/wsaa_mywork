# %% [markdown]
# ## **Implementing a rest server:**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# *1. How to design restful API:*
#
# ![image.png](attachment:image.png)

# %% [markdown]
# *2. How will write code:*
#
# -   Make app server with skeleton functions
# -   make very basic app server and test it
# -   Add a function and url map for each of the functions designed in the interface. Each function should just return text saying what they are. Test them using CURL.

# %% [markdown]
# *3. want to implement the restful API:*
#
# -   Create a DAO (data access object): python module that handles all data access.
# -   can store in database or lists.
#
# Use DAO methods instead of doing it in the route directly
# -   get all -->test
# -   find by id-->test
# -   create -->test
# -   update -->test
# -   delete -->test

# %% [markdown]
# *4. Integrate with server:*
#
# -   get all
# -   find by id
# -   create ()
# -   update
# -   delete
# -   test all

# %% [markdown]
# Can now write server/webservice that can deal with restful api endpoints.
#
# ***
# ### **End**
