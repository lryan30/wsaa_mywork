# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# SQL--> Structured query language
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# SQL is a text based language that allows yout to manipulate a database.
