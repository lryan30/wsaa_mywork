# %% [markdown]
# https://andrewbeatty1.pythonanywhere.com/bookviewer.html

# %% [markdown]
# -   need to know html to make a user interface to a restful API
# -   AJAX: jquery which uses ajax to interact with restful api. andrewbeattypythonanywhere/books

# %% [markdown]
# make your own restful api and own html interface for it.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# -  Bootstrap:--> free, open-source CSS framework used to quickly build responsive, mobile-friendly, and visually appealing websites.
#
# It gives you pre-written CSS and JavaScript code so you don’t have to start from scratch when styling buttons, layouts, forms, or navigation bars.
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <html>
#     <head>
#         <title>my page</title>
#         <!-- CSS only -->
#         <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css" rel="stylesheet" integrity="sha384-Zenh87qX5JnK2Jl0vWa8Ck2rdkQ2Bzep5IDxbcnCeuOxjzrPF/et3URy9Bv1WTRi" crossorigin="anonymous">
#     </head>
#     <body>
#         books
#         <table class="table">
#             <tr>
#                 <th>title</th>
#                 <th>author</th>
#             </tr>
#             <tr>
#                 <td>harry potter</td>
#                 <td>jk</td>
#             </tr>
#             <tr>
#                 <td>harry potter</td>
#                 <td>jk</td>
#             </tr>
#         </table>
#
#         <div id="myform">
#             name <input type="text" value="enter your name" id="name"/><br/>
#             password <input type="password" id="password_input"/><br/>
#             gender <br/>
#             male <input type="radio" name="gender" value = "male" id="male"/>
#             female <input type="radio" name="gender" value = "female" id="female"/><br/>
#
#              <input type="submit" value="hit here" id="submit"/><br/>
#              <button id="other_button">other one</button>
#
#         </div>
#
#         <script>
#             console.log("hello mum")
#         </script>
#     </body>
# </html>
