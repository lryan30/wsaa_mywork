# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# *If statements:*
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# *For Loop:*
#
# ![image.png](attachment:image.png)

# %% [markdown]
# For loops iterate through counts, arrays or objects.

# %% [markdown]
# ![image.png](attachment:image.png)
